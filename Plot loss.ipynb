# %%
from  glob import glob
from time import sleep
from baselines.bench import load_results
from matplotlib import pylab as plt
import numpy as np
import argparse
import os
import pandas as pd


plt.figure(figsize=(10, 10))
my_dir = '/workspace7/Unity3D/gabriele/arc_challenge/RUNS/exp_15/loss_monitor.csv'
data = pd.read_csv(my_dir) 
roll = 10
data['f'] = (data.index)
# data[['f', 'train_loss']].rolling(roll).mean().plot('f', 'train_loss',legend=False)
# data[['f', 'val_loss']].rolling(roll).mean().plot('f', 'val_loss',legend=False)
plt.plot(data['f'], data['train_loss'], color= 'blue')
plt.plot(data['f'], data['val_loss'], color='blue')

my_dir = '/workspace7/Unity3D/gabriele/arc_challenge/RUNS/exp_14/loss_monitor.csv'
data = pd.read_csv(my_dir) 
roll = 10
data['f'] = (data.index)
# data[['f', 'train_loss']].rolling(roll).mean().plot('f', 'train_loss',legend=False)
# data[['f', 'val_loss']].rolling(roll).mean().plot('f', 'val_loss',legend=False)
plt.plot(data['f'], data['train_loss'], color = 'green')
plt.plot(data['f'], data['val_loss'], color= 'green')

my_dir = '/workspace7/Unity3D/gabriele/arc_challenge/RUNS/exp_12/loss_monitor.csv'
data = pd.read_csv(my_dir) 
roll = 10
data['f'] = (data.index)
# data[['f', 'train_loss']].rolling(roll).mean().plot('f', 'train_loss',legend=False)
# data[['f', 'val_loss']].rolling(roll).mean().plot('f', 'val_loss',legend=False)
plt.plot(data['f'], data['train_loss'], color='red')
plt.plot(data['f'], data['val_loss'], color='red')

my_dir = '/workspace7/Unity3D/gabriele/arc_challenge/RUNS/exp_11/loss_monitor.csv'
data = pd.read_csv(my_dir) 
roll = 10
data['f'] = (data.index)
# data[['f', 'train_loss']].rolling(roll).mean().plot('f', 'train_loss',legend=False)
# data[['f', 'val_loss']].rolling(roll).mean().plot('f', 'val_loss',legend=False)
plt.plot(data['f'], data['train_loss'], color='gray')
plt.plot(data['f'], data['val_loss'], color='gray')


# my_dir = '/workspace7/Unity3D/gabriele/arc_challenge/RUNS/exp_12/loss_monitor.csv'
# data = pd.read_csv(my_dir) 
# roll = 10
# data['f'] = (data.index)
# # data[['f', 'train_loss']].rolling(roll).mean().plot('f', 'train_loss',legend=False)
# # data[['f', 'val_loss']].rolling(roll).mean().plot('f', 'val_loss',legend=False)
# plt.plot(data['f'], data['train_loss'], color='orange')
# plt.plot(data['f'], data['val_loss'], color='orange')



plt.ylabel("train loss")
plt.xlabel('N. steps (M)')
plt.legend()
plt.xlim(0,1000)
plt.ylim(0,40)
# Out:
# No handles with labels found to put in legend.
# (0, 40)

# %%
my_dir = '/workspace7/Unity3D/gabriele/arc_challenge/RUNS/exp_5/imgs/loss_monitor.csv'
data = pd.read_csv(my_dir) 
roll = 10
data['f'] = (data.index)
data[['f', 'loss']].rolling(roll).mean().plot('f', 'loss',legend=False)
plt.ylabel("train loss")
plt.xlabel('N. epochs')
plt.title(str(my_dir).upper())
plt.legend(['batch_size=80, lr=0.0001'])

# %%
my_dir = '/workspace7/Unity3D/gabriele/arc_challenge/RUNS/exp_8/loss_monitor.csv'
data = pd.read_csv(my_dir) 
roll = 10
data['f'] = (data.index)
data[['f', 'loss']].rolling(roll).mean().plot('f', 'loss',legend=False)
plt.ylabel("train loss")
plt.xlabel('N. epochs')
plt.title(str(my_dir).upper())
plt.legend(['no encoder,batch_size=80, lr=0.0001'])
